# %%
import numpy as np #operaciones matriciales y con vectores
import pandas as pd #tratamiento de datos
import matplotlib.pyplot as plt #gráficos
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression # modelos lineales
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split #metodo de particionamiento de datasets para evaluación
from sklearn.model_selection import cross_val_score #protocolo de evaluación
from sklearn import datasets, metrics
from sklearn import preprocessing
from sklearn.metrics import make_scorer
import warnings
warnings.filterwarnings('ignore')

# %%
col_Headers = ["EventType","RegisterDate","StopID","Odometer","Longitude","Latitude", "TaskID","LineID","TripID","DatagramID","DatagramTimestamp","BusID"]
missing_values = ["n/a", "na", "--", "NaT","%WARN%"]
df = pd.read_csv('m_datagrams.csv',',',dtype={"EventType": str, "RegisterDate": str, "StopID": str,"Odometer": str,"Longitude": str,"Latitude": str, "TaskID": str,"LineID": str,"TripID": str,"DatagramID": str,"DatagramTimestamp": str,"BusID": str},names = col_Headers, na_values = missing_values)

# %%
df['DatagramTimestamp']= pd.to_datetime(df['DatagramTimestamp']) 
df['DatagramDate'] = pd.to_datetime(df['DatagramTimestamp']).dt.date
df['DatagramTime'] = pd.to_datetime(df['DatagramTimestamp']).dt.time
df = df.drop('DatagramTimestamp',1)
col_Headers = ["EventType","RegisterDate","StopID","Odometer","Longitude","Latitude", "TaskID","LineID","TripID","DatagramID","DatagramDate","DatagramTime","BusID"]
df = df[col_Headers]
df['DatagramDate'] = pd.to_datetime(df.DatagramDate)

# %% [markdown]
# ## Analisis Exploratorio de Datos

# %% [markdown]
# Un análisis exploratorio de los datos verificando la calidad de los datos (tipos de las variables, valores inválidos, excepciones, valores faltantes, etc.), utilizando gráficos para poder entender las distribuciones de los datos e identificar posibles problemas.

# %%
df.head()
# Out:
#   EventType RegisterDate  StopID Odometer   Longitude  Latitude TaskID LineID  \
# 0        19   2018-09-04  501051        1  -764871900  34451717    572    140
# 1        19   2018-09-04  502103     1063  -765463867  33977717   1023    217
# 2         7   2018-09-04  515152       24  -765076783  34191300    705   2471
# 3        19   2018-09-04  502650      788  -764913067  34220317    143    150
# 4         7   2018-09-04  515006       91  -765005167  34115933    705   2471
#
#   TripID  DatagramID DatagramDate DatagramTime BusID
# 0    548  5661359158   2018-09-03     07:05:57   714
# 1    882  5661362653   2018-09-03     07:07:19   311
# 2     43  5661362655   2018-09-03     07:07:19   796
# 3    389  5661367800   2018-09-03     07:09:21   561
# 4     43  5661348896   2018-09-03     07:01:54   796

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242473 entries, 0 to 2242472
# Data columns (total 13 columns):
# EventType       object
# RegisterDate    object
# StopID          object
# Odometer        object
# Longitude       object
# Latitude        object
# TaskID          object
# LineID          object
# TripID          object
# DatagramID      object
# DatagramDate    datetime64[ns]
# DatagramTime    object
# BusID           object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 222.4+ MB

# %%
data_missing= df.isnull().sum()/len(df)*100
data_missing
# Out:
# EventType        0.000000
# RegisterDate    31.830350
# StopID           0.000089
# Odometer         0.000089
# Longitude        0.000089
# Latitude         0.000089
# TaskID           0.000089
# LineID           0.000089
# TripID           0.000089
# DatagramID       0.000089
# DatagramDate    32.079494
# DatagramTime    32.079494
# BusID            0.000089
# dtype: float64

# %%
df.tail()
# Out:
#                                                  EventType RegisterDate  \
# 2242468                                                  8   2018-06-29
# 2242469                                                  5   2018-06-29
# 2242470                                                  8   2018-06-29
# 2242471  WARN: The method class org.apache.commons.logg...          NaN
# 2242472  WARN: Please see http://www.slf4j.org/codes.ht...          NaN
#
#          StopID Odometer   Longitude  Latitude TaskID LineID TripID  \
# 2242468  502301       -1  -765284850  34415983    145   2104    165
# 2242469  502551      597  -765102900  34897600    931   2274    491
# 2242470  502551      597          -1        -1    931   2274    491
# 2242471     NaN      NaN         NaN       NaN    NaN    NaN    NaN
# 2242472     NaN      NaN         NaN       NaN    NaN    NaN    NaN
#
#          DatagramID DatagramDate DatagramTime BusID
# 2242468  5511316915   2018-06-28     15:44:47    30
# 2242469  5511337393   2018-06-28     15:54:22    69
# 2242470  5511337432   2018-06-28     15:54:23    69
# 2242471         NaN          NaT          NaT   NaN
# 2242472         NaN          NaT          NaT   NaN

# %%
df.describe(include="all")
# Out:
#        EventType RegisterDate   StopID Odometer Longitude Latitude   TaskID  \
# count    2242473      1528686  2242471  2242471   2242471  2242471  2242471
# unique        34          243     2120    12571     65753   108930     4304
# top            7   2019-03-30       -1       -1        -1       -1       -1
# freq      320439        11502    78210   524456     76703    76703    62608
#
#          LineID   TripID  DatagramID DatagramDate DatagramTime    BusID
# count   2242471  2242471     2242471      1523099      1523099  2242471
# unique      111     2798     2242471          242        75959      853
# top        2273       -1  5918650658   2019-03-14     07:14:58      147
# freq     101770    64520           1        12400           64    52793

# %% [markdown]
# # Limpieza de Datos
# Se realiza una limpieza de datos para poder iniciar a interpretar el comportamiento de los datos.
# Para esto procedemos a realizar las siguientes operaciones:
# - Hallar el porcentaje de Missing Values
# - Buscar y eliminar los datos duplicados
# - Eliminar los valores nulos que se encuentren en los datos

# %% [markdown]
# ### Missing Values
#
# Standard Type = NaN,"", "%WARN%"
#
#
# Estos son los missing values reconocidos en el Dataset

# %% [markdown]
# #### Los -1 y los 0 son buses que van sin tarea, sin operación, son viajes de posicionamiento o de salida

# %%
print("Porcentajes de -1 por cada columna : ")
i=0
for a in df.columns:
  print(a,":",(df[a].values=='-1').sum()/len(df)*100,"%")
  i+=1
# Out:
# Porcentajes de -1 por cada columna :
# EventType : 0.0 %
# RegisterDate : 0.0 %
# StopID : 3.487667410042395 %
# Odometer : 23.387394184902117 %
# Longitude : 3.420464817190664 %
# Latitude : 3.420464817190664 %
# TaskID : 2.7919176730332986 %
# LineID : 2.3678768930551226 %
# TripID : 2.8771806840037764 %
# DatagramID : 0.0 %
# DatagramDate : 0.0 %
# DatagramTime : 0.0 %
# BusID : 0.0 %

# %% [markdown]
# ### Busqueda de Valores Duplicados

# %%
duplicateDFRow = df[df.duplicated()]
print(duplicateDFRow)
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %% [markdown]
# ### Eliminación de valores Nulos

# %%
df =df.dropna()

# %%
df2= df[(df['EventType']=='12') | (df['EventType']=='23')]
df2 = df2.sort_values(by=['DatagramDate'])
df2.head()
# Out:
#        EventType RegisterDate  StopID Odometer   Longitude  Latitude TaskID  \
# 974764        23   2018-05-31  504015       -1  -764934100  34891600    925
# 975148        23   2018-06-01  514415      394  -764852700  34239233    861
# 975159        23   2018-06-01  502301       -1  -765255267  33711000    507
# 975165        23   2018-06-01  511281       86  -765256833  33695983    507
# 975179        23   2018-06-01  504015      123  -764919283  34901517     -1
#
#        LineID TripID  DatagramID DatagramDate DatagramTime BusID
# 974764    283     70  5444493335   2018-05-31     05:04:33   150
# 975148   2842    490  5447291293   2018-05-31     06:34:16   151
# 975159   2121   1623  5447294485   2018-05-31     06:35:32   642
# 975165   2121   1623  5447295826   2018-05-31     06:36:03   642
# 975179    283     -1  5447299613   2018-05-31     06:37:33   150

# %%
temp= df2.BusID.value_counts().to_frame()
BusIDCounts= temp.reset_index()
BusIDCounts.columns=['BusID','Counts']
BusIDCounts.head()
# Out:
#   BusID  Counts
# 0   255    8585
# 1   640    6097
# 2   571    5817
# 3   153    4602
# 4   638    4014

# %%
plt.rc('figure',figsize=(15,8))

# %%
x = BusIDCounts['BusID']
y = BusIDCounts['Counts']

fig, ax = plt.subplots()
ax.scatter(x,y)
plt.show()

# %%
sns.boxplot(y=BusIDCounts['Counts'])

# %%
BusIDCounts[BusIDCounts['Counts'] < 4000]
# Out:
#     BusID  Counts
# 5     642    3818
# 6     158    3808
# 7     150    3569
# 8     147    3500
# 9     132    3420
# 10    156    2987
# 11    151    2671
# 12    135    2399
# 13    169    2247
# 14   1095    2223
# 15    217    2027
# 16   1031    1947
# 17    176    1869
# 18   1070    1847
# 19    898    1824
# 20    161    1811
# 21   1196    1776
# 22    166    1767
# 23   1174    1767
# 24    224    1672
# 25    809    1601
# 26    818    1578
# 27   1072    1519
# 28   1115    1454
# 29   1105    1306
# 30    163    1259
# 31    810    1248
# 32    226    1164
# 33    889    1153
# 34     10    1138
# ..    ...     ...
# 653    71       1
# 654   383       1
# 655   872       1
# 656  1243       1
# 657     9       1
# 658   941       1
# 659  1236       1
# 660   428       1
# 661   186       1
# 662    38       1
# 663   267       1
# 664  1250       1
# 665   950       1
# 666   285       1
# 667  1051       1
# 668   706       1
# 669   149       1
# 670   233       1
# 671   200       1
# 672  1249       1
# 673   167       1
# 674   264       1
# 675   774       1
# 676    43       1
# 677    42       1
# 678   902       1
# 679   637       1
# 680   100       1
# 681   282       1
# 682   413       1
#
# [678 rows x 2 columns]

# %%
BusIDCounts2 = BusIDCounts[BusIDCounts['Counts'] < 100]
x2 = BusIDCounts2['BusID']
y2 = BusIDCounts2['Counts']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %%
temp= df2.BusID.value_counts().to_frame()
BusIDCounts= temp.reset_index()
BusIDCounts.columns=['BusID','Counts']
BusIDCounts2 = BusIDCounts[BusIDCounts['Counts'] < 100]
BusIDCounts2.head()
# Out:
#    BusID  Counts
# 58  1093      83
# 59  1171      60
# 60  1107      60
# 61   960      60
# 62   788      59

# %% [markdown]
# # Buses selected to graph
# - Bus Id: 255  --> EventCount = 8585
# - Bus Id: 640  --> EventCount = 6097
# - Bus Id: 571  --> EventCount = 5817
# - Bus Id: 132 --> EventCount = 3420
# - Bus Id: 135 --> EventCount = 2399
# - Bus Id: 898 --> EventCount = 1824
# - Bus Id: 1093 --> EventCount = 83
# - Bus Id: 1171 --> EventCount = 60
# - Bus Id: 1107 --> EventCount = 60

# %% [markdown]
# ## Bus 255
#
# ### General View:

# %%
dfBus1 = df2[(df2['BusID'] == '255')]
dfBus1_1 = dfBus1['DatagramDate'].drop_duplicates().to_frame()
dfBus1_1
# Out:
#         DatagramDate
# 465267    2018-05-31
# 586744    2018-06-01
# 1097629   2018-06-02
# 592028    2018-06-03
# 1100193   2018-06-04
# 2065673   2018-06-05
# 428556    2018-06-06
# 2063078   2018-06-07
# 2072476   2018-06-08
# 1192059   2018-06-09
# 1241976   2018-06-10
# 2076550   2018-06-11
# 297376    2018-06-12
# 431087    2018-06-13
# 306271    2018-06-14
# 309472    2018-06-15
# 1099295   2018-06-16
# 501373    2018-06-18
# 81317     2018-06-19
# 693390    2018-06-20
# 2062827   2018-06-21
# 2079973   2018-06-22
# 97064     2018-06-23
# 2077994   2018-06-25
# 503160    2018-06-26
# 2074854   2018-06-27
# 302371    2018-06-28
# 100603    2018-06-29
# 608013    2018-06-30
# 15187     2018-07-01
# ...              ...
# 995565    2019-03-31
# 340381    2019-05-01
# 905685    2019-05-02
# 908522    2019-05-03
# 347959    2019-05-04
# 770994    2019-05-06
# 909426    2019-05-07
# 404057    2019-05-08
# 353198    2019-05-09
# 776974    2019-05-10
# 412825    2019-05-11
# 1734100   2019-05-13
# 783504    2019-05-14
# 865304    2019-05-15
# 411047    2019-05-16
# 847059    2019-05-17
# 1750170   2019-05-18
# 1740466   2019-05-19
# 380432    2019-05-20
# 1222488   2019-05-21
# 1639003   2019-05-22
# 895460    2019-05-23
# 1225754   2019-05-24
# 915489    2019-05-25
# 721795    2019-05-26
# 897838    2019-05-27
# 829771    2019-05-28
# 1295283   2019-05-29
# 1292859   2019-05-30
# 8081             NaT
#
# [220 rows x 1 columns]

# %%
size = dfBus1_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus1_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 640
#
# ### General View:

# %%
dfBus2 = df2[(df2['BusID'] == '640')]
dfBus2_1 = dfBus2['DatagramDate'].drop_duplicates().to_frame()
dfBus2_1
# Out:
#         DatagramDate
# 184       2018-09-06
# 636       2018-09-04
# 924       2018-09-05
# 4214      2018-09-16
# 4306      2018-09-15
# 5138      2018-09-17
# 13718     2018-07-04
# 14237     2018-07-12
# 16678     2018-07-11
# 17166     2018-07-09
# 17902     2018-07-05
# 18977     2018-07-10
# 23271     2018-06-11
# 23389     2018-06-08
# 23561     2018-06-10
# 23581     2018-06-12
# 24963     2018-06-05
# 25009     2018-06-14
# 25033     2018-06-01
# 26701     2018-06-16
# 27293     2018-06-19
# 27730     2018-06-09
# 30702     2018-06-04
# 32387     2018-07-17
# 32455     2018-07-19
# 32796     2018-07-13
# 33026     2018-07-14
# 36463     2018-07-18
# 41652     2018-09-07
# 43840     2018-09-10
# ...              ...
# 632860    2019-02-07
# 646721    2019-02-01
# 655974    2019-02-14
# 659896    2019-02-13
# 704403    2018-09-27
# 707516    2018-10-09
# 717809    2019-05-19
# 718022    2019-05-18
# 723395    2019-05-21
# 743109    2019-03-05
# 743163    2019-03-04
# 751458    2019-03-06
# 782360    2019-05-17
# 800659    2019-02-21
# 806635    2018-11-01
# 810202    2018-11-11
# 816448    2018-11-13
# 921406    2018-11-28
# 923582    2018-11-30
# 952737    2018-07-25
# 973544    2018-10-02
# 974699    2018-05-31
# 990412    2018-10-30
# 1118213   2019-02-05
# 1119030   2019-02-03
# 1228939   2018-10-27
# 1231127   2018-10-31
# 1309651   2018-10-28
# 1933436   2018-09-09
# 1947597   2018-11-08
#
# [202 rows x 1 columns]

# %%
size = dfBus2_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus2_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 571
#
# ### General View:

# %%
dfBus3 = df2[(df2['BusID'] == '571')]
dfBus3_1 = dfBus3['DatagramDate'].drop_duplicates().to_frame()
dfBus3_1
# Out:
#         DatagramDate
# 12        2018-09-03
# 522       2018-09-05
# 1116      2018-09-04
# 1574      2018-09-06
# 5369      2018-09-14
# 5764      2018-09-12
# 6309      2018-09-17
# 6455      2018-09-11
# 6862      2018-09-15
# 13353     2018-07-04
# 13910     2018-07-12
# 14129     2018-07-03
# 15005     2018-07-05
# 15668     2018-07-13
# 16433     2018-07-07
# 16474     2018-07-11
# 18721     2018-07-10
# 20378     2018-07-06
# 22135     2018-07-14
# 23808     2018-06-02
# 24014     2018-06-07
# 24056     2018-06-05
# 24311     2018-06-15
# 24762     2018-06-14
# 25290     2018-06-01
# 26232     2018-06-22
# 26690     2018-06-16
# 27316     2018-06-06
# 28416     2018-06-28
# 28448     2018-06-19
# ...              ...
# 538932    2018-10-21
# 562613    2018-10-03
# 594189    2018-06-04
# 608508    2018-06-11
# 628516    2019-02-07
# 629505    2019-02-08
# 630512    2019-02-10
# 631405    2019-02-06
# 632608    2019-02-12
# 644305    2019-02-05
# 647179    2019-02-01
# 703393    2018-09-30
# 726233    2019-03-06
# 738033    2019-05-25
# 743196    2019-03-04
# 818531    2019-03-05
# 880308    2019-03-03
# 979071    2018-07-20
# 988172    2018-10-29
# 1108759   2018-10-30
# 1118828   2019-02-03
# 1167977   2018-07-21
# 1182990   2018-11-12
# 1206593   2019-03-10
# 1228754   2018-10-31
# 1257108   2019-03-30
# 1615167   2018-10-07
# 1620877   2018-10-14
# 2061999   2018-07-28
# 2208347   2018-11-30
#
# [209 rows x 1 columns]

# %%
size = dfBus3_1.size
plt.rc('figure',figsize=(15,10))
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus3_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 132
#
# ### General View:

# %%
dfBus4 = df2[(df2['BusID'] == '132')]
dfBus4_1 = dfBus4['DatagramDate'].drop_duplicates().to_frame()
dfBus4_1
# Out:
#         DatagramDate
# 2152      2018-09-06
# 3359      2018-09-07
# 3566      2018-09-05
# 4546      2018-09-15
# 5933      2018-09-14
# 5987      2018-09-13
# 26286     2018-06-15
# 27906     2018-06-11
# 28668     2018-06-23
# 31021     2018-06-16
# 31319     2018-06-04
# 31990     2018-06-14
# 43837     2018-09-10
# 46502     2018-09-12
# 50084     2018-09-18
# 50491     2018-09-27
# 56758     2018-07-12
# 62378     2019-02-01
# 62721     2019-02-04
# 72065     2018-11-02
# 83239     2018-06-22
# 83509     2018-06-26
# 104717    2018-06-19
# 121893    2019-03-13
# 124030    2019-03-15
# 125671    2018-10-14
# 125809    2018-10-12
# 129845    2019-03-09
# 131918    2019-03-14
# 131986    2019-03-11
# ...              ...
# 952029    2018-07-25
# 990662    2018-10-30
# 999860    2018-06-12
# 1096814   2018-06-06
# 1104454   2018-10-17
# 1106761   2018-09-03
# 1117080   2019-02-05
# 1117462   2019-02-03
# 1127857   2018-11-29
# 1128686   2018-11-28
# 1142179   2018-10-09
# 1150030   2018-06-30
# 1151710   2018-06-20
# 1155697   2018-06-21
# 1176397   2018-09-26
# 1178000   2018-09-24
# 1211163   2018-10-18
# 1233961   2018-10-29
# 1251559   2018-07-04
# 1309457   2018-10-24
# 1328426   2018-10-31
# 1344286   2019-02-11
# 1508459   2018-11-27
# 1850144   2018-10-19
# 1854829   2018-10-15
# 1870824   2018-10-27
# 1918883   2018-11-01
# 1951029   2018-11-06
# 1963016   2018-11-13
# 2038539   2019-02-22
#
# [154 rows x 1 columns]

# %%
size = dfBus4_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus4_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 135
#
# ### General View:

# %%
dfBus5 = df2[(df2['BusID'] == '135')]
dfBus5_1 = dfBus5['DatagramDate'].drop_duplicates().to_frame()
dfBus5_1
# Out:
#         DatagramDate
# 62225     2019-02-02
# 63323     2019-02-04
# 121378    2019-03-14
# 121821    2019-03-11
# 121935    2019-03-13
# 123591    2019-03-19
# 123945    2019-03-15
# 129627    2019-03-09
# 129882    2019-03-12
# 131694    2019-03-16
# 133159    2019-03-10
# 136882    2019-03-08
# 148283    2019-03-23
# 148496    2019-03-21
# 149551    2019-03-18
# 150477    2019-03-20
# 151953    2019-03-22
# 159036    2019-03-27
# 159177    2019-03-26
# 161768    2019-03-28
# 175596    2019-02-28
# 178107    2019-02-18
# 178631    2019-02-27
# 178939    2019-02-25
# 178979    2019-02-24
# 185209    2019-02-22
# 185548    2019-02-20
# 186095    2019-02-23
# 186937    2019-02-15
# 186991    2019-02-26
# ...              ...
# 437090    2019-03-30
# 444862    2019-03-29
# 566720    2018-10-08
# 628262    2019-02-07
# 630919    2019-02-08
# 631316    2019-02-06
# 633763    2019-02-12
# 635182    2019-02-10
# 640159    2019-02-05
# 648917    2019-02-11
# 650333    2019-02-14
# 654037    2019-02-13
# 668176    2019-03-17
# 717824    2019-05-19
# 718025    2019-05-18
# 719760    2019-05-22
# 723688    2019-05-21
# 742097    2019-03-07
# 747275    2019-03-06
# 771766    2019-05-06
# 779782    2019-05-15
# 781329    2019-05-12
# 788363    2019-02-19
# 821466    2019-03-05
# 823198    2019-03-04
# 834452    2019-05-17
# 880200    2019-03-03
# 905537    2019-05-02
# 1117314   2019-02-01
# 1118822   2019-02-03
#
# [88 rows x 1 columns]

# %%
size = dfBus5_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus5_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 898
#
# ### General View:

# %%
dfBus6 = df2[(df2['BusID'] == '898')]
dfBus6_1 = dfBus6['DatagramDate'].drop_duplicates().to_frame()
dfBus6_1
# Out:
#         DatagramDate
# 267       2018-09-04
# 528       2018-09-05
# 2162      2018-09-06
# 2533      2018-09-03
# 4813      2018-09-16
# 13333     2018-07-06
# 15555     2018-07-03
# 17926     2018-07-07
# 19698     2018-07-05
# 23839     2018-06-06
# 25188     2018-06-18
# 26024     2018-06-24
# 29753     2018-06-20
# 30960     2018-06-05
# 32479     2018-07-19
# 32765     2018-07-15
# 33240     2018-07-11
# 33460     2018-07-09
# 35060     2018-07-17
# 39917     2018-07-20
# 40942     2018-07-18
# 41811     2018-09-11
# 42220     2018-09-09
# 42759     2018-09-07
# 43390     2018-09-08
# 44731     2018-09-10
# 48645     2018-09-12
# 50371     2018-09-24
# 52171     2018-09-26
# 62334     2019-02-01
# ...              ...
# 628481    2019-02-06
# 630230    2019-02-09
# 631011    2019-02-11
# 635073    2019-02-10
# 642897    2019-02-05
# 719947    2019-05-20
# 745460    2019-03-06
# 746822    2019-03-04
# 782172    2019-05-11
# 785639    2018-07-14
# 787340    2019-02-19
# 810847    2018-11-11
# 818984    2019-03-07
# 820512    2019-03-05
# 834477    2019-05-17
# 835316    2019-05-15
# 860684    2019-05-16
# 865610    2019-05-18
# 938215    2018-07-27
# 952392    2018-07-30
# 990797    2018-10-30
# 1109368   2018-10-26
# 1119607   2019-02-04
# 1233393   2018-10-29
# 1253277   2018-07-13
# 1263344   2019-03-29
# 1297839   2018-10-02
# 1848351   2018-10-06
# 1866924   2018-10-28
# 1975554   2018-11-27
#
# [208 rows x 1 columns]

# %%
size = dfBus6_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus6_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 1093
#
# ### General View:

# %%
dfBus7 = df2[(df2['BusID'] == '1093')]
dfBus7_1 = dfBus7['DatagramDate'].drop_duplicates().to_frame()
dfBus7_1
# Out:
#         DatagramDate
# 432       2018-09-05
# 15272     2018-07-08
# 22828     2018-06-09
# 34496     2018-07-04
# 96922     2018-06-25
# 129389    2019-03-14
# 192727    2018-10-12
# 193756    2018-10-14
# 258532    2018-09-24
# 432876    2019-03-25
# 440125    2019-03-29
# 489711    2018-11-13
# 506595    2018-09-22
# 660782    2019-02-14
# 673789    2019-03-15
# 682166    2018-07-19
# 690974    2018-06-13
# 811479    2018-11-09
# 884897    2019-03-01
# 958993    2018-06-02
# 1093329   2018-07-26
# 1164090   2018-07-03
# 1175403   2018-09-26
# 1242340   2018-06-11
# 1262421   2019-03-27
# 1666608   2018-10-28
# 1698230   2018-09-29
# 1956005   2018-11-16
# 1971736   2018-11-28
# 2018970   2018-07-14
# 2060054   2018-07-22

# %%
size = dfBus7_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus7_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 1171
#
# ### General View:

# %%
dfBus8 = df2[(df2['BusID'] == '1171')]
dfBus8_1 = dfBus8['DatagramDate'].drop_duplicates().to_frame()
dfBus8_1
# Out:
#         DatagramDate
# 7320      2018-09-15
# 56391     2018-07-06
# 246094    2018-11-22
# 321567    2019-05-29
# 333363    2019-02-23
# 435917    2019-03-27
# 587006    2018-06-07
# 624641    2018-11-23
# 653334    2019-02-15
# 656797    2019-02-14
# 729350    2019-03-09
# 793342    2019-02-25
# 840174    2019-05-22
# 900556    2019-05-27
# 993040    2019-03-28
# 2032970   2019-02-13

# %%
size = dfBus8_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus8_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Bus 1107
#
# ### General View:

# %%
dfBus9 = df2[(df2['BusID'] == '1107')]
dfBus9_1 = dfBus9['DatagramDate'].drop_duplicates().to_frame()
dfBus9_1
# Out:
#         DatagramDate
# 551       2018-09-03
# 37786     2018-07-18
# 103263    2018-06-22
# 104522    2018-06-29
# 110739    2018-11-23
# 169382    2018-11-06
# 173738    2018-11-10
# 217377    2018-09-18
# 224661    2018-09-12
# 356013    2019-02-13
# 549789    2018-07-15
# 617823    2018-11-17
# 651858    2019-02-11
# 701954    2018-09-19
# 955276    2018-07-24
# 1166453   2018-07-05
# 1680442   2018-09-06
# 2053481   2018-07-19

# %%
size = dfBus9_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus9_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
plt.show()
