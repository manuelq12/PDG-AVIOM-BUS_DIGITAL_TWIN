# %%
import numpy as np #operaciones matriciales y con vectores
import pandas as pd #tratamiento de datos
import matplotlib.pyplot as plt #gráficos
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression # modelos lineales
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split #metodo de particionamiento de datasets para evaluación
from sklearn.model_selection import cross_val_score #protocolo de evaluación
from sklearn import datasets, metrics
from sklearn import preprocessing
from sklearn.metrics import make_scorer
import warnings
warnings.filterwarnings('ignore')

# %%
col_Headers = ["EventType","RegisterDate","StopID","Odometer","Longitude","Latitude", "TaskID","LineID","TripID","DatagramID","DatagramTimestamp","BusID"]
missing_values = ["n/a", "na", "--", "NaT","%WARN%"]
df = pd.read_csv('m_datagrams.csv',',',dtype={"EventType": str, "RegisterDate": str, "StopID": str,"Odometer": str,"Longitude": str,"Latitude": str, "TaskID": str,"LineID": str,"TripID": str,"DatagramID": str,"DatagramTimestamp": str,"BusID": str},names = col_Headers, na_values = missing_values)

# %%
df['DatagramTimestamp']= pd.to_datetime(df['DatagramTimestamp']) 
df['DatagramDate'] = pd.to_datetime(df['DatagramTimestamp']).dt.date
df['DatagramTime'] = pd.to_datetime(df['DatagramTimestamp']).dt.time
df = df.drop('DatagramTimestamp',1)
col_Headers = ["EventType","RegisterDate","StopID","Odometer","Longitude","Latitude", "TaskID","LineID","TripID","DatagramID","DatagramDate","DatagramTime","BusID"]
df = df[col_Headers]
df['DatagramDate'] = pd.to_datetime(df.DatagramDate)
df['RegisterDate'] = pd.to_datetime(df.RegisterDate)
df['Odometer'] = pd.to_numeric(df.Odometer, downcast ='signed')
df['Longitude'] = pd.to_numeric(df.Longitude, downcast ='signed') 
df['Latitude'] = pd.to_numeric(df.Latitude, downcast ='signed')

# %% [markdown]
# ## Analisis Exploratorio de Datos

# %% [markdown]
# Un análisis exploratorio de los datos verificando la calidad de los datos (tipos de las variables, valores inválidos, excepciones, valores faltantes, etc.), utilizando gráficos para poder entender las distribuciones de los datos e identificar posibles problemas.

# %%
df.head()
# Out:
#   EventType RegisterDate  StopID  Odometer    Longitude    Latitude TaskID  \
# 0        19   2018-09-04  501051       1.0 -764871900.0  34451717.0    572
# 1        19   2018-09-04  502103    1063.0 -765463867.0  33977717.0   1023
# 2         7   2018-09-04  515152      24.0 -765076783.0  34191300.0    705
# 3        19   2018-09-04  502650     788.0 -764913067.0  34220317.0    143
# 4         7   2018-09-04  515006      91.0 -765005167.0  34115933.0    705
#
#   LineID TripID  DatagramID DatagramDate DatagramTime BusID
# 0    140    548  5661359158   2018-09-03     07:05:57   714
# 1    217    882  5661362653   2018-09-03     07:07:19   311
# 2   2471     43  5661362655   2018-09-03     07:07:19   796
# 3    150    389  5661367800   2018-09-03     07:09:21   561
# 4   2471     43  5661348896   2018-09-03     07:01:54   796

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242473 entries, 0 to 2242472
# Data columns (total 13 columns):
# EventType       object
# RegisterDate    datetime64[ns]
# StopID          object
# Odometer        float64
# Longitude       float64
# Latitude        float64
# TaskID          object
# LineID          object
# TripID          object
# DatagramID      object
# DatagramDate    datetime64[ns]
# DatagramTime    object
# BusID           object
# dtypes: datetime64[ns](2), float64(3), object(8)
# memory usage: 222.4+ MB

# %%
data_missing= df.isnull().sum()/len(df)*100
data_missing
# Out:
# EventType        0.000000
# RegisterDate    31.830350
# StopID           0.000089
# Odometer         0.000089
# Longitude        0.000089
# Latitude         0.000089
# TaskID           0.000089
# LineID           0.000089
# TripID           0.000089
# DatagramID       0.000089
# DatagramDate    32.079494
# DatagramTime    32.079494
# BusID            0.000089
# dtype: float64

# %%
df.tail()
# Out:
#                                                  EventType RegisterDate  \
# 2242468                                                  8   2018-06-29
# 2242469                                                  5   2018-06-29
# 2242470                                                  8   2018-06-29
# 2242471  WARN: The method class org.apache.commons.logg...          NaT
# 2242472  WARN: Please see http://www.slf4j.org/codes.ht...          NaT
#
#          StopID  Odometer    Longitude    Latitude TaskID LineID TripID  \
# 2242468  502301      -1.0 -765284850.0  34415983.0    145   2104    165
# 2242469  502551     597.0 -765102900.0  34897600.0    931   2274    491
# 2242470  502551     597.0         -1.0        -1.0    931   2274    491
# 2242471     NaN       NaN          NaN         NaN    NaN    NaN    NaN
# 2242472     NaN       NaN          NaN         NaN    NaN    NaN    NaN
#
#          DatagramID DatagramDate DatagramTime BusID
# ...

# %%
df.describe(include="all")
# Out:
#        EventType         RegisterDate   StopID      Odometer     Longitude  \
# count    2242473              1528686  2242471  2.242471e+06  2.242471e+06
# unique        34                  243     2120           NaN           NaN
# top            7  2019-03-30 00:00:00       -1           NaN           NaN
# freq      320439                11502    78210           NaN           NaN
# first        NaN  2018-05-31 00:00:00      NaN           NaN           NaN
# last         NaN  2019-05-31 00:00:00      NaN           NaN           NaN
# mean         NaN                  NaN      NaN  2.603127e+02 -7.389955e+08
# std          NaN                  NaN      NaN  2.874157e+03  1.390729e+08
# min          NaN                  NaN      NaN -1.000000e+00 -7.667183e+08
# 25%          NaN                  NaN      NaN  1.000000e+00 -7.653106e+08
# 50%          NaN                  NaN      NaN  5.000000e+01 -7.652198e+08
# ...

# %% [markdown]
# # Limpieza de Datos
# Se realiza una limpieza de datos para poder iniciar a interpretar el comportamiento de los datos.
# Para esto procedemos a realizar las siguientes operaciones:
# - Hallar el porcentaje de Missing Values
# - Buscar y eliminar los datos duplicados
# - Eliminar los valores nulos que se encuentren en los datos

# %% [markdown]
# ### Missing Values
#
# Standard Type = NaN,"", "%WARN%"
#
#
# Estos son los missing values reconocidos en el Dataset

# %% [markdown]
# #### Los -1 y los 0 son buses que van sin tarea, sin operación, son viajes de posicionamiento o de salida

# %%
df[df['DatagramDate'] == '-1']
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %%
df[df['RegisterDate'] == '-1']
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %%
df[df['Odometer'] == '-1']
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %%
df[df['Longitude'] == '-1']
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %%
df[df['Latitude'] == '-1']
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %%
print("Porcentajes de -1 por cada columna : ")
i=0
for a in df.columns:
    try:
        print(a,":",(df[a].values=='-1').sum()/len(df)*100,"%")
       
    except:
        print(a,":",0/len(df)*100,"%")
    i+=1
# Out:
# Porcentajes de -1 por cada columna :
# EventType : 0.0 %
# RegisterDate : 0.0 %
# StopID : 3.487667410042395 %
# Odometer : 0.0 %
# Longitude : 0.0 %
# Latitude : 0.0 %
# TaskID : 2.7919176730332986 %
# LineID : 2.3678768930551226 %
# TripID : 2.8771806840037764 %
# DatagramID : 0.0 %
# DatagramDate : 0.0 %
# DatagramTime : 0.0 %
# BusID : 0.0 %

# %% [markdown]
# ### Busqueda de Valores Duplicados

# %%
duplicateDFRow = df[df.duplicated()]
print(duplicateDFRow)
# Out:
# Empty DataFrame
# Columns: [EventType, RegisterDate, StopID, Odometer, Longitude, Latitude, TaskID, LineID, TripID, DatagramID, DatagramDate, DatagramTime, BusID]
# Index: []

# %% [markdown]
# ### Eliminación de valores Nulos

# %%
df =df.dropna()

# %%
df2= df[(df['EventType']=='12') | (df['EventType']=='23')]
df2 = df2.sort_values(by=['DatagramDate'])
df2.head()
# Out:
#        EventType RegisterDate  StopID  Odometer    Longitude    Latitude  \
# 974735        23   2018-05-31  516139     860.0 -765249767.0  33851300.0
# 462488        23   2018-06-01  514026      33.0 -764679667.0  34357783.0
# 462508        12   2018-06-01  501855      15.0 -765482183.0  34155650.0
# 974729        23   2018-05-31  502650      17.0 -764905867.0  34213800.0
# 974728        23   2018-05-31  514071       1.0 -764776233.0  34247217.0
#
#        TaskID LineID TripID  DatagramID DatagramDate DatagramTime BusID
# 974735    779   2212      3  5444475832   2018-05-31     04:54:52   640
# 462488    864   3411    168  5448932853   2018-05-31     13:17:13   926
# 462508    178    421    238  5448941807   2018-05-31     13:22:12   959
# 974729    129   2842    445  5444468262   2018-05-31     04:50:09   158
# 974728    861   2842     18  5444465444   2018-05-31     04:48:17   151

# %%
temp= df2.BusID.value_counts().to_frame()
BusIDCounts= temp.reset_index()
BusIDCounts.columns=['BusID','Counts']
BusIDCounts.head()
# Out:
#   BusID  Counts
# 0   255    8585
# 1   640    6097
# 2   571    5817
# 3   153    4602
# 4   638    4014

# %%
plt.rc('figure',figsize=(15,8))

# %%
x = BusIDCounts['BusID']
y = BusIDCounts['Counts']

fig, ax = plt.subplots()
ax.scatter(x,y)
ax.set_xlabel("BusID")
ax.set_ylabel("Event Count")
ax.set_title('BusID vs EventType (12-23) Count')
plt.show()

# %%
sns.boxplot(y=BusIDCounts['Counts'])

# %%
BusIDCounts[BusIDCounts['Counts'] < 4000]
# Out:
#     BusID  Counts
# 5     642    3818
# 6     158    3808
# 7     150    3569
# 8     147    3500
# 9     132    3420
# 10    156    2987
# 11    151    2671
# 12    135    2399
# 13    169    2247
# 14   1095    2223
# 15    217    2027
# 16   1031    1947
# 17    176    1869
# 18   1070    1847
# 19    898    1824
# 20    161    1811
# 21   1196    1776
# 22    166    1767
# 23   1174    1767
# 24    224    1672
# 25    809    1601
# 26    818    1578
# 27   1072    1519
# 28   1115    1454
# 29   1105    1306
# 30    163    1259
# 31    810    1248
# 32    226    1164
# 33    889    1153
# 34     10    1138
# ..    ...     ...
# 653   868       1
# 654   211       1
# 655   277       1
# 656   149       1
# 657   428       1
# 658  1249       1
# 659  1243       1
# 660  1250       1
# 661   233       1
# 662   100       1
# 663     4       1
# 664   413       1
# 665  1140       1
# 666     9       1
# 667   101       1
# 668   934       1
# 669  1235       1
# 670   917       1
# ...

# %%
BusIDCounts2 = BusIDCounts[BusIDCounts['Counts'] < 100]
x2 = BusIDCounts2['BusID']
y2 = BusIDCounts2['Counts']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("BusID")
ax2.set_ylabel("Event Count")
ax2.set_title('BusID vs EventType (12-23) Count < 100')
plt.show()

# %%
temp= df2.BusID.value_counts().to_frame()
BusIDCounts= temp.reset_index()
BusIDCounts.columns=['BusID','Counts']
BusIDCounts2 = BusIDCounts[BusIDCounts['Counts'] < 100]
BusIDCounts2.head()
# Out:
#    BusID  Counts
# 58  1093      83
# 59  1107      60
# 60   960      60
# 61  1171      60
# 62   788      59

# %% [markdown]
# # Buses selected to graph
# - Bus Id: 255  --> EventCount = 8585
# - Bus Id: 640  --> EventCount = 6097
# - Bus Id: 571  --> EventCount = 5817
# - Bus Id: 132 --> EventCount = 3420
# - Bus Id: 135 --> EventCount = 2399
# - Bus Id: 898 --> EventCount = 1824
# - Bus Id: 1093 --> EventCount = 83
# - Bus Id: 1171 --> EventCount = 60
# - Bus Id: 1107 --> EventCount = 60

# %% [markdown]
# ## Bus 255
#
# ### General View:

# %%
dfBus1 = df2[(df2['BusID'] == '255')]
dfBus1_1 = dfBus1['DatagramDate'].drop_duplicates().to_frame()
dfBus1_1
# Out:
#         DatagramDate
# 974710    2018-05-31
# 587398    2018-06-01
# 2065321   2018-06-02
# 77923     2018-06-03
# 960008    2018-06-04
# 2065691   2018-06-05
# 590231    2018-06-06
# 77402     2018-06-07
# 688112    2018-06-08
# 1001692   2018-06-09
# 1243374   2018-06-10
# 2076550   2018-06-11
# 309791    2018-06-12
# 590619    2018-06-13
# 1150255   2018-06-14
# 1192838   2018-06-15
# 310806    2018-06-16
# 297667    2018-06-18
# 304576    2018-06-19
# 83594     2018-06-20
# 1149088   2018-06-21
# 504341    2018-06-22
# 1188310   2018-06-23
# 83213     2018-06-25
# 501408    2018-06-26
# 106273    2018-06-27
# 1187522   2018-06-28
# 1157209   2018-06-29
# 610760    2018-06-30
# 543157    2018-07-01
# ...              ...
# 1710543   2019-03-30
# 995565    2019-03-31
# 1723968   2019-05-01
# 908177    2019-05-02
# 342803    2019-05-03
# 908557    2019-05-04
# 737500    2019-05-06
# 775639    2019-05-07
# 406826    2019-05-08
# 878590    2019-05-09
# 779478    2019-05-10
# ...

# %%
size = dfBus1_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus1_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 255: General View")
plt.ylim(0.99,1.01)
plt.show()

# %%
plt.rc('figure',figsize=(16,5))

# %%
y2 = [(x/x) for x in range (1,59)]
x2 = dfBus1_1['DatagramDate'].iloc[:58]
startDate = dfBus1_1['DatagramDate'].iloc[0]
finishDate = dfBus1_1['DatagramDate'].iloc[57]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 255: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,85)]
x2 = dfBus1_1['DatagramDate'].iloc[58:142]
startDate = dfBus1_1['DatagramDate'].iloc[58]
finishDate = dfBus1_1['DatagramDate'].iloc[141]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 255: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 90)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,50)]
x2 = dfBus1_1['DatagramDate'].iloc[142:191]
startDate = dfBus1_1['DatagramDate'].iloc[142]
finishDate = dfBus1_1['DatagramDate'].iloc[190]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 255: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,(dfBus1_1.size -190))]
x2 = dfBus1_1['DatagramDate'].iloc[191:]
startDate = dfBus1_1['DatagramDate'].iloc[191]
finishDate = dfBus1_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="black")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 255: Fourth Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 640
#
# ### General View:

# %%
dfBus2 = df2[(df2['BusID'] == '640')]
dfBus2_1 = dfBus2['DatagramDate'].drop_duplicates().to_frame()
dfBus2_1
# Out:
#         DatagramDate
# 974735    2018-05-31
# 429333    2018-06-01
# 693799    2018-06-02
# 307856    2018-06-03
# 307047    2018-06-04
# 1247081   2018-06-05
# 590252    2018-06-06
# 312208    2018-06-08
# 309347    2018-06-09
# 594404    2018-06-10
# 689538    2018-06-11
# 309786    2018-06-12
# 498033    2018-06-14
# 431191    2018-06-15
# 99400     2018-06-16
# 310945    2018-06-17
# 500283    2018-06-18
# 28459     2018-06-19
# 2053910   2018-07-04
# 2042789   2018-07-05
# 292873    2018-07-06
# 33991     2018-07-09
# 784687    2018-07-10
# 32517     2018-07-11
# 1252829   2018-07-12
# 57503     2018-07-13
# 1251751   2018-07-14
# 934844    2018-07-16
# 1169605   2018-07-17
# 933166    2018-07-18
# ...              ...
# 1517747   2019-03-29
# 1516619   2019-03-30
# 995780    2019-03-31
# 1724232   2019-05-01
# 1723655   2019-05-02
# 343360    2019-05-03
# 912920    2019-05-04
# 346038    2019-05-05
# 734058    2019-05-06
# 775198    2019-05-07
# 406910    2019-05-08
# ...

# %%
size = dfBus2_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus2_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 640: General View")
plt.show()

# %%
y2 = [(x/x) for x in range (1,42)]
x2 = dfBus2_1['DatagramDate'].iloc[:41]
startDate = dfBus2_1['DatagramDate'].iloc[0]
finishDate = dfBus2_1['DatagramDate'].iloc[40]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 640: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,83)]
x2 = dfBus2_1['DatagramDate'].iloc[41:123]
startDate = dfBus2_1['DatagramDate'].iloc[41]
finishDate = dfBus2_1['DatagramDate'].iloc[122]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 640: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 90)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,53)]
x2 = dfBus2_1['DatagramDate'].iloc[123:175]
startDate = dfBus2_1['DatagramDate'].iloc[123]
finishDate = dfBus2_1['DatagramDate'].iloc[174]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 640: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,(dfBus2_1.size-174))]
x2 = dfBus2_1['DatagramDate'].iloc[175:]
startDate = dfBus2_1['DatagramDate'].iloc[175]
finishDate = dfBus2_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="black")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 640: Fourth Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 571
#
# ### General View:

# %%
dfBus3 = df2[(df2['BusID'] == '571')]
dfBus3_1 = dfBus3['DatagramDate'].drop_duplicates().to_frame()
dfBus3_1
# Out:
#         DatagramDate
# 462727    2018-05-31
# 429420    2018-06-01
# 1097683   2018-06-02
# 594189    2018-06-04
# 959426    2018-06-05
# 959512    2018-06-06
# 1101258   2018-06-07
# 996795    2018-06-08
# 690324    2018-06-09
# 77748     2018-06-10
# 693724    2018-06-11
# 687017    2018-06-12
# 688628    2018-06-13
# 496903    2018-06-14
# 98081     2018-06-15
# 1101666   2018-06-16
# 499613    2018-06-17
# 103621    2018-06-18
# 502771    2018-06-19
# 2082310   2018-06-20
# 300033    2018-06-21
# 26232     2018-06-22
# 1189714   2018-06-23
# 1187584   2018-06-24
# 313802    2018-06-25
# 2077495   2018-06-26
# 1190749   2018-06-27
# 1187271   2018-06-28
# 1154226   2018-06-29
# 610797    2018-06-30
# ...              ...
# 1777243   2019-03-03
# 1765260   2019-03-04
# 1779542   2019-03-05
# 818492    2019-03-06
# 829295    2019-03-07
# 1780408   2019-03-08
# 1767083   2019-03-09
# 1783290   2019-03-10
# 146799    2019-03-11
# 985702    2019-03-12
# 131372    2019-03-13
# ...

# %%
size = dfBus3_1.size
plt.rc('figure',figsize=(15,10))
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus3_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 571: General View")
plt.show()

# %%
y2 = [(x/x) for x in range (1,61)]
x2 = dfBus3_1['DatagramDate'].iloc[:60]
startDate = dfBus3_1['DatagramDate'].iloc[0]
finishDate = dfBus3_1['DatagramDate'].iloc[59]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 571: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,90)]
x2 = dfBus3_1['DatagramDate'].iloc[60:149]
startDate = dfBus3_1['DatagramDate'].iloc[60]
finishDate = dfBus3_1['DatagramDate'].iloc[148]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 571: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 90)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,58)]
x2 = dfBus3_1['DatagramDate'].iloc[149:206]
startDate = dfBus3_1['DatagramDate'].iloc[149]
finishDate = dfBus3_1['DatagramDate'].iloc[205]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 571: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,4)]
x2 = dfBus3_1['DatagramDate'].iloc[206:]
startDate = dfBus3_1['DatagramDate'].iloc[206]
finishDate = dfBus3_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="black")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 571: Fourth Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 132
#
# ### General View:

# %%
dfBus4 = df2[(df2['BusID'] == '132')]
dfBus4_1 = dfBus4['DatagramDate'].drop_duplicates().to_frame()
dfBus4_1
# Out:
#         DatagramDate
# 429784    2018-06-01
# 31319     2018-06-04
# 996022    2018-06-05
# 1096814   2018-06-06
# 1101191   2018-06-07
# 28485     2018-06-11
# 999860    2018-06-12
# 588591    2018-06-14
# 2077242   2018-06-15
# 103328    2018-06-16
# 307612    2018-06-17
# 2066194   2018-06-18
# 104717    2018-06-19
# 1151710   2018-06-20
# 1155697   2018-06-21
# 608637    2018-06-22
# 2080704   2018-06-23
# 594473    2018-06-24
# 313795    2018-06-25
# 301570    2018-06-26
# 610532    2018-06-27
# 313481    2018-06-29
# 1150030   2018-06-30
# 1251559   2018-07-04
# 56758     2018-07-12
# 358696    2018-07-20
# 254250    2018-07-23
# 952029    2018-07-25
# 1002465   2018-07-30
# 466435    2018-07-31
# ...              ...
# 148331    2019-03-20
# 148745    2019-03-21
# 1796020   2019-03-23
# 150293    2019-03-26
# 443527    2019-03-27
# 1515247   2019-03-28
# 1518011   2019-03-29
# 1258563   2019-03-30
# 1724004   2019-05-01
# 1723605   2019-05-02
# 907141    2019-05-03
# ...

# %%
size = dfBus4_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus4_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 132: General View")
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,31)]
x2 = dfBus4_1['DatagramDate'].iloc[:30]
startDate = dfBus4_1['DatagramDate'].iloc[0]
finishDate = dfBus4_1['DatagramDate'].iloc[29]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 132: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,61)]
x2 = dfBus4_1['DatagramDate'].iloc[30:90]
startDate = dfBus4_1['DatagramDate'].iloc[30]
finishDate = dfBus4_1['DatagramDate'].iloc[89]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 132: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 90)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,43)]
x2 = dfBus4_1['DatagramDate'].iloc[90:132]
startDate = dfBus4_1['DatagramDate'].iloc[90]
finishDate = dfBus4_1['DatagramDate'].iloc[131]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 132: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,dfBus4_1.size - 131)]
x2 = dfBus4_1['DatagramDate'].iloc[132:]
startDate = dfBus4_1['DatagramDate'].iloc[132]
finishDate = dfBus4_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="black")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 132: Fourth Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 135
#
# ### General View:

# %%
dfBus5 = df2[(df2['BusID'] == '135')]
dfBus5_1 = dfBus5['DatagramDate'].drop_duplicates().to_frame()
dfBus5_1
# Out:
#         DatagramDate
# 566720    2018-10-08
# 2013358   2019-02-01
# 1600572   2019-02-02
# 1701180   2019-02-03
# 1118301   2019-02-04
# 644708    2019-02-05
# 1325742   2019-02-06
# 635574    2019-02-07
# 651701    2019-02-08
# 355044    2019-02-09
# 648455    2019-02-10
# 648917    2019-02-11
# 633789    2019-02-12
# 1346280   2019-02-13
# 1347699   2019-02-14
# 1502835   2019-02-15
# 355965    2019-02-16
# 638533    2019-02-17
# 355123    2019-02-18
# 2035906   2019-02-19
# 806166    2019-02-20
# 2035965   2019-02-21
# 185562    2019-02-22
# 335699    2019-02-23
# 361169    2019-02-24
# 1248504   2019-02-25
# 1138305   2019-02-26
# 182813    2019-02-27
# 791579    2019-02-28
# 883453    2019-03-01
# ...              ...
# 1724275   2019-05-01
# 905537    2019-05-02
# 907581    2019-05-03
# 910513    2019-05-04
# 342353    2019-05-05
# 771766    2019-05-06
# 1732758   2019-05-07
# 737560    2019-05-08
# 871731    2019-05-09
# 779486    2019-05-10
# 398794    2019-05-11
# ...

# %%
size = dfBus5_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus5_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 135: General View")
ax2.set_xticks(x2[:1])
plt.xticks(rotation = 70)
plt.show()

# %%
y2 = [(x/x) for x in range (1,58)]
x2 = dfBus5_1['DatagramDate'].iloc[1:58]
startDate = dfBus5_1['DatagramDate'].iloc[1]
finishDate = dfBus5_1['DatagramDate'].iloc[57]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 135: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,31)]
x2 = dfBus5_1['DatagramDate'].iloc[58:]
startDate = dfBus5_1['DatagramDate'].iloc[58]
finishDate = dfBus5_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 135: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 898
#
# ### General View:

# %%
dfBus6 = df2[(df2['BusID'] == '898')]
dfBus6_1 = dfBus6['DatagramDate'].drop_duplicates().to_frame()
dfBus6_1
# Out:
#         DatagramDate
# 975421    2018-05-31
# 430824    2018-06-01
# 957281    2018-06-02
# 308007    2018-06-03
# 309101    2018-06-04
# 1246955   2018-06-05
# 957877    2018-06-06
# 1096175   2018-06-07
# 297640    2018-06-08
# 996647    2018-06-09
# 2065932   2018-06-15
# 1192339   2018-06-17
# 299083    2018-06-18
# 610399    2018-06-19
# 1190559   2018-06-20
# 606835    2018-06-21
# 2067890   2018-06-22
# 2074812   2018-06-23
# 2074747   2018-06-24
# 79176     2018-06-25
# 1149791   2018-06-26
# 1151268   2018-06-27
# 305203    2018-06-28
# 1151104   2018-06-29
# 304048    2018-06-30
# 679340    2018-07-03
# 2041505   2018-07-04
# 2052207   2018-07-05
# 2042357   2018-07-06
# 1165987   2018-07-07
# ...              ...
# 1795966   2019-03-28
# 1520020   2019-03-29
# 436965    2019-03-30
# 1724492   2019-05-01
# 1719112   2019-05-02
# 908578    2019-05-03
# 730069    2019-05-05
# 731738    2019-05-06
# 404566    2019-05-07
# 773428    2019-05-08
# 413937    2019-05-09
# ...

# %%
size = dfBus6_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus6_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 898: General View")
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,52)]
x2 = dfBus6_1['DatagramDate'].iloc[:51]
startDate = dfBus6_1['DatagramDate'].iloc[0]
finishDate = dfBus6_1['DatagramDate'].iloc[50]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 898: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,76)]
x2 = dfBus6_1['DatagramDate'].iloc[51:126]
startDate = dfBus6_1['DatagramDate'].iloc[51]
finishDate = dfBus6_1['DatagramDate'].iloc[125]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 898: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 90)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,56)]
x2 = dfBus6_1['DatagramDate'].iloc[126:181]
startDate = dfBus6_1['DatagramDate'].iloc[126]
finishDate = dfBus6_1['DatagramDate'].iloc[180]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 898: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,(dfBus6_1.size-180))]
x2 = dfBus6_1['DatagramDate'].iloc[181:]
startDate = dfBus6_1['DatagramDate'].iloc[181]
finishDate = dfBus6_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="black")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 898: Fourth Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 1093
#
# ### General View:

# %%
dfBus7 = df2[(df2['BusID'] == '1093')]
dfBus7_1 = dfBus7['DatagramDate'].drop_duplicates().to_frame()
dfBus7_1
# Out:
#         DatagramDate
# 958993    2018-06-02
# 686906    2018-06-09
# 1242340   2018-06-11
# 690974    2018-06-13
# 97015     2018-06-25
# 1164105   2018-07-03
# 34496     2018-07-04
# 15272     2018-07-08
# 2018970   2018-07-14
# 682166    2018-07-19
# 2060054   2018-07-22
# 1093329   2018-07-26
# 432       2018-09-05
# 507122    2018-09-22
# 258601    2018-09-24
# 1175403   2018-09-26
# 1698230   2018-09-29
# 192727    2018-10-12
# 193756    2018-10-14
# 1666634   2018-10-28
# 1623215   2018-11-09
# 489711    2018-11-13
# 1956005   2018-11-16
# 1971736   2018-11-28
# 660782    2019-02-14
# 884897    2019-03-01
# 143280    2019-03-14
# 673789    2019-03-15
# 432882    2019-03-25
# 1262421   2019-03-27
# 1791440   2019-03-29

# %%
size = dfBus7_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus7_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1093: General View")
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,13)]
x2 = dfBus7_1['DatagramDate'].iloc[:12]
startDate = dfBus7_1['DatagramDate'].iloc[0]
finishDate = dfBus7_1['DatagramDate'].iloc[11]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1093: First Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,13)]
x2 = dfBus7_1['DatagramDate'].iloc[12:24]
startDate = dfBus7_1['DatagramDate'].iloc[12]
finishDate = dfBus7_1['DatagramDate'].iloc[23]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="g")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1093: Second Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,(dfBus7_1.size -23))]
x2 = dfBus7_1['DatagramDate'].iloc[24:]
startDate = dfBus7_1['DatagramDate'].iloc[24]
finishDate = dfBus7_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="r")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1093: Third Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 1171
#
# ### General View:

# %%
dfBus8 = df2[(df2['BusID'] == '1171')]
dfBus8_1 = dfBus8['DatagramDate'].drop_duplicates().to_frame()
dfBus8_1
# Out:
#         DatagramDate
# 587006    2018-06-07
# 1252729   2018-07-06
# 7320      2018-09-15
# 246094    2018-11-22
# 1974712   2018-11-23
# 2033331   2019-02-13
# 656797    2019-02-14
# 1504916   2019-02-15
# 333363    2019-02-23
# 793342    2019-02-25
# 729350    2019-03-09
# 437131    2019-03-27
# 1794838   2019-03-28
# 840174    2019-05-22
# 900556    2019-05-27
# 321567    2019-05-29

# %%
size = dfBus8_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus8_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1171: General View")
ax2.set_xticks(x2[:5])
plt.xticks(rotation = 70)
plt.ylim(0.99,1.01)
plt.show()

# %%
y2 = [(x/x) for x in range (1,(dfBus8_1.size - 4))]
x2 = dfBus8_1['DatagramDate'].iloc[5:]
startDate = dfBus8_1['DatagramDate'].iloc[5]
finishDate = dfBus8_1['DatagramDate'].iloc[-1]
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2,c ="y")
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1171: Last Section")
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.subplots_adjust(bottom = 0.15)
plt.ylim(0.99,1.01)
plt.show()

# %% [markdown]
# ## Bus 1107
#
# ### General View:

# %%
dfBus9 = df2[(df2['BusID'] == '1107')]
dfBus9_1 = dfBus9['DatagramDate'].drop_duplicates().to_frame()
dfBus9_1
# Out:
#         DatagramDate
# 103263    2018-06-22
# 104522    2018-06-29
# 1166453   2018-07-05
# 549789    2018-07-15
# 39638     2018-07-18
# 2061313   2018-07-19
# 955276    2018-07-24
# 1415258   2018-09-03
# 1680639   2018-09-06
# 226105    2018-09-12
# 217377    2018-09-18
# 701954    2018-09-19
# 169382    2018-11-06
# 811736    2018-11-10
# 617823    2018-11-17
# 110739    2018-11-23
# 652145    2019-02-11
# 658285    2019-02-13

# %%
size = dfBus9_1.size
y2 = [(x/x) for x in range (1,size+1)]
x2 = dfBus9_1['DatagramDate']
fig,ax2 = plt.subplots()
ax2.scatter(x2,y2)
ax2.set_xlabel("DatagramDate")
ax2.set_ylabel("Count")
ax2.set_title("Bus 1107: General View")
plt.ylim(0.99,1.01)
ax2.set_xticks(x2)
plt.xticks(rotation = 70)
plt.show()
